# %%
import numpy as np
import glob
import sys
sys.path.append("../")
import Acdc 
import Analysis 
import matplotlib.pyplot as plt 
#plt.style.use("~/evanstyle.mplstyle")

# %%
#Structure of this dict:
#key: acdc number
#value: dict with the following keys
#   obj: Acdc object itself
#   config: configuration file path 
#   infiles: list of input data files for that board

#this set of boards is used in the July 2024 proton data at test-beam
acdcs = {44:{"obj":None, "config":"../configs/acdc44.yml", "infiles": [], "pedfiles": []}, \
        43:{"obj":None, "config":"../configs/acdc43.yml", "infiles": [], "pedfiles": []}}

#Configure some data filepaths
#you'll likely want to keep paths as we may be committing/pushing
#multiple paths. Just use a comment
datadir = "../../data/20240701ProtonDataFTBF/"


#initialize the acdc objects
for acdc_num, a in acdcs.items():
    a["obj"] = Acdc.Acdc(a["config"])

    #the configuration is now parsed, so we can find which station id
    #in order to parse the filetag at the end of the data filenames. 
    bnum = a["obj"].c["station_id"]
    #find all the data files for this board
    a["infiles"] = glob.glob(datadir + f"Raw_Proton*b{bnum}.txt")
    #find all the pedestal files for this board
    a["pedfiles"] = glob.glob(datadir + f"Raw_test*b{bnum}.txt")

    #short operation of calibrating the board based on the calibration file
    a["obj"].calibrate_board()
    a["obj"].process_files(a["infiles"][:5])
# Out:
# ACDC instantiated
#   ACDC:    44
#   LAPPD:   157
#   ACC:     0
#   Station: 0
#
# ACDC voltage calibrated with VCCs
# ACDC sample times NOT calibrated
#
# Importing data from "../../data/20240701ProtonDataFTBF/Raw_ProtonData_20240701_134450_b0.txt"
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# not enough values to unpack (expected 2, got 1)
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# /Users/ejangelico/anaconda3/envs/llnl/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# not enough values to unpack (expected 2, got 1)
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# `x0` is infeasible.
# Wraparound Error
# `x0` is infeasible.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# `x0` is infeasible.
# Wraparound Error
# Wraparound Error
# `x0` is infeasible.
# `x0` is infeasible.
# Importing data from "../../data/20240701ProtonDataFTBF/Raw_ProtonData_20240701_133333_b0.txt"
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# not enough values to unpack (expected 2, got 1)
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Wraparound Error
# Optimal parameters not found: Number of calls to function has reached maxfev = 1000.
# Wraparound Error
# Wraparound Error
# Wraparound Error
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 32
#      30 #short operation of calibrating the board based on the calibration file
#      31 a["obj"].calibrate_board()
# ---> 32 a["obj"].process_files(a["infiles"][:5])
#
# File ~/Documents/Stanford/LAPPD/code/LAPPD_TOF_Analysis/notebooks/../Acdc.py:605, in Acdc.process_files(self, file_list)
#     603 else:
#     604 	for file_name in file_list:
# --> 605 		single_event_rq_dict = self.process_single_file(file_name)
#     606 		for key in single_event_rq_dict.keys():
#     607 			if key == "num_skipped":
#
# File ~/Documents/Stanford/LAPPD/code/LAPPD_TOF_Analysis/notebooks/../Acdc.py:579, in Acdc.process_single_file(self, file_name)
#     577 times_320, times, data_raw = self.import_raw_data(file_name)
#     578 preprocess_dict = self.preprocess_data(data_raw, times_320)
# --> 579 rq_dict = self.calc_positions(preprocess_dict, times)
#     580 return rq_dict
#
# File ~/Documents/Stanford/LAPPD/code/LAPPD_TOF_Analysis/notebooks/../Acdc.py:419, in Acdc.calc_positions(self, preprocess_dict, times)
#     417 elif self.c["VAR_SINE_FREQ"]:
#     418 	param_bounds = ([0.025, 1.4, -3*np.pi, 0.6], [0.4, 1.75, 3*np.pi, 0.9])
# --> 419 	popt, pcov = curve_fit(util.sin_const_back, xsin, ysin, p0=p0, bounds=param_bounds)
#     420 else:
#     421 	popt, pcov = curve_fit(util.sin_const_back_250, xsin, ysin, p0=(p0[0], p0[2], p0[3]), bounds=([0.025, -3*np.pi, 0.6], [0.4, 3*np.pi, 0.9]))
#
# File ~/anaconda3/envs/llnl/lib/python3.11/site-packages/scipy/optimize/_minpack_py.py:974, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     971 if 'max_nfev' not in kwargs:
#     972     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 974 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     975                     **kwargs)
#     977 if not res.success:
#     978     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File ~/anaconda3/envs/llnl/lib/python3.11/site-packages/scipy/optimize/_lsq/least_squares.py:940, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     936     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     937                           max_nfev, x_scale, diff_step)
#     939 elif method == 'trf':
# --> 940     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     941                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     942                  tr_options.copy(), verbose)
#     944 elif method == 'dogbox':
#     945     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File ~/anaconda3/envs/llnl/lib/python3.11/site-packages/scipy/optimize/_lsq/trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File ~/anaconda3/envs/llnl/lib/python3.11/site-packages/scipy/optimize/_lsq/trf.py:334, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     331     p_h = S.dot(p_S)
#     333 p = d * p_h  # Trust-region solution in the original space.
# --> 334 step, step_h, predicted_reduction = select_step(
#     335     x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     337 x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
#     338 f_new = fun(x_new)
#
# File ~/anaconda3/envs/llnl/lib/python3.11/site-packages/scipy/optimize/_lsq/trf.py:168, in select_step(x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     166 # Check if reflection step is available.
#     167 if r_stride_l <= r_stride_u:
# --> 168     a, b, c = build_quadratic_1d(J_h, g_h, r_h, s0=p_h, diag=diag_h)
#     169     r_stride, r_value = minimize_quadratic_1d(
#     170         a, b, r_stride_l, r_stride_u, c=c)
#     171     r_h *= r_stride
#
# File ~/anaconda3/envs/llnl/lib/python3.11/site-packages/scipy/optimize/_lsq/common.py:296, in build_quadratic_1d(J, g, s, diag, s0)
#     294     if diag is not None:
#     295         b += np.dot(s0 * diag, s)
# --> 296         c += 0.5 * np.dot(s0 * diag, s0)
#     297     return a, b, c
#     298 else:
#
# File ~/anaconda3/envs/llnl/lib/python3.11/site-packages/numpy/core/multiarray.py:741, in dot(a, b, out)
#     671     """
#     672     result_type(*arrays_and_dtypes)
#     673
#    (...)
#     736
#     737     """
#     738     return arrays_and_dtypes
# --> 741 @array_function_from_c_func_and_dispatcher(_multiarray_umath.dot)
#     742 def dot(a, b, out=None):
#     743     """
#     744     dot(a, b, out=None)
#     745
#    (...)
#     829
#     830     """
#     831     return (a, b, out)
#
# KeyboardInterrupt:

# %%
for acdc_num, a in acdcs.items():
    a["obj"].save_npz(datadir+f"reduced_acdc{acdc_num}.npz")

print("Finished saving files")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 for acdc_num, a in acdcs.items():
# ----> 2     a["obj"].save_npz(datadir+f"reduced_acdc{acdc_num}.npz")
#       4 print("Finished saving files")
#
# AttributeError: 'NoneType' object has no attribute 'save_npz'
